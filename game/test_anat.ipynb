# %%
import pandas as pd
import os
import random

# %%
wellnames=['F1',
 'F2',
 'I1',
 'I2',
 'I3',
 'I4',
 'I5',
 'I6',
 'P1',
 'P3',
 'P4',
 'P5',
 'P6',
 'PS1',
 'PS2']

# %%
df=pd.read_excel("C:/Users/Анатолий/Desktop/gitdocs/simgame/game/dataspace/FlexOil/Мероприятия РиЭНМ FlexOil.xlsx")

# %%
df=df.drop([0,1,2,3,4,5],axis=0)

# %%
df
# Out:
#     Курс Исследования скважин и пластов 2018           Unnamed: 1  \
# 6                           Название команды     Дата мероприятия
# 7                                   Проверка  2017-01-01 00:00:00
# 8                                    FlexOil  2020-07-01 01:00:00
# 9                                    FlexOil  2020-07-02 01:00:00
# 10                                   FlexOil  2020-07-03 01:00:00
# 11                                   FlexOil  2020-07-04 01:00:00
# 12                                   FlexOil  2020-07-05 01:00:00
# 13                                   FlexOil  2020-07-07 01:00:00
# 14                                   FlexOil  2020-07-08 01:00:00
# 15                                   FlexOil  2020-07-09 01:00:00
# 16                                   FlexOil  2020-07-10 01:00:00
# 17                                   FlexOil  2020-07-11 01:00:00
# 18                                   FlexOil  2020-07-12 01:00:00
# ...

# %%
df=df.rename(columns={'Unnamed: 1':'Date','Unnamed: 2':'vid','Unnamed: 7':'vdp','Unnamed: 3':'name','Unnamed: 12':'Price'})

# %%
perf={}

# %%
for name in wellnames:
    perf[name]=2500

# %%
#a=df[df.vid=='Реперфорация']

# %%
for i in df[df.vid=='Реперфорация'].name: 
    perf[i]=df[df.vid=='Реперфорация'].vdp[df[df.vid=='Реперфорация'].name==i].values[0]

# %%
#perf

# %%
#a['vdp'][a['vdp'].index[-1]]

# %%
counter=pd.DataFrame()

# %%
counter['Date']=pd.to_datetime(df.Date.drop([6],axis=0))

# %%
counter['Price']=df.Price.drop([6],axis=0)

# %%
counter=counter.dropna()

# %%
counter
# Out:
#                  Date Price
# 7 2017-01-01 00:00:00    10
# 8 2020-07-01 01:00:00   100
# 9 2020-07-02 01:00:00   100

# %%
 def make_month_counter(self, team_name):
        self.current_dir = os.getcwd()
        self.team_name = team_name
        self.path_to_team_directory = self.current_dir + "\\resultspace\\" + team_name + "\\"
        self.df = pd.read_csv(self.path_to_team_directory + "sim_result.csv")
        names=self.df.columns[1:]
        wellnames=[]
        price=10000
        for n in names:
            a=n.split(':')
            b=a[1]
            if b in wellnames:
                break
            else:
                wellnames.append(b)
        self.wellnames = wellnames

        time = pd.to_datetime(self.df.time)
        self.report=pd.DataFrame()
        self.report['Time']=time
        self.report.reindex(self.report['Time'])

        for name in self.wellnames:
            self.report[name + '. Дебит по нефти, м3/сут']=self.df['WOPR:'+name]
        self.df['Money']=price*self.df.sum()
        self.report = self.report.resample('M', on='Time').last()
        self.report = self.report.interpolate()
        del self.report['Time']
